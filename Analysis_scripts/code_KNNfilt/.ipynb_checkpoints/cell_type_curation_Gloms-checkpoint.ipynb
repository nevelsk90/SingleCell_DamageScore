# %%
import matplotlib.pyplot as plt
import alphashape
import glob
from descartes import PolygonPatch
from shapely.geometry import Point
from os import path
from KNN_filtration import *

# %% [markdown]
# ### Function defns

# %%
# Takes in data matrix containing info for cell type to-be-curated and alphashape of structure in which 
# the cell type must be removed
# Returns filtered cell type data
def celltype_excluder(dat,alpha_shape):    
    points = np.array(dat[['x','y']])
    is_in_struct_arr = []
    for coord in points:
        is_in_struct = alpha_shape.intersects(Point(coord))
        is_in_struct_arr.append(is_in_struct)

    not_in_struct = [not i for i in is_in_struct_arr]
    result = dat[not_in_struct]
    
    return(result)

# Takes in data matrix containing info for cell type to-be-curated and alphashape of structure in which
# the cell must be maintained
# Returns filtered cell type data
def celltype_includer(dat,alpha_shape):
    points = np.array(dat[['x','y']])
    is_in_struct_arr = []
    for coord in points:
        is_in_struct = alpha_shape.intersects(Point(coord))
        is_in_struct_arr.append(is_in_struct)
    
    result = dat[is_in_struct_arr]
    
    return(result)

# %% [markdown]
# ### Initialization

# %%
# cell type to-be-curated
cell_type = 'Podocyte'
# region of kidney 
section = 'cortex'

# input_path is path to file with all beads x features in an array, 
# features = {'barcode','x','y'}
input_path = '/media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713333_ogBeadLocations.csv'
coords = pd.read_csv(input_path,index_col=0)
all_coords = np.array(coords)

# input_path is path to file with beads x features for marker beads in section of interest in an array
# features = {'barcode','x','y'}
input_path = '/media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim/GSM5713333_BeadLocationsPodoTim.csv'
markers = pd.read_csv(input_path,index_col=0)

# %% [markdown]
# ### Remove markers from relevant structures

# %%
# Glomeruli, granular cell clusters for CD-IC, CD-PC, DCT, PCT, and TAL
# MD for CD-IC, CD-PC, DCT, and PCT

if cell_type not in ['Podocyte','GC','MD']:
    has_glom = False
    has_gc = False
    has_MD = False
    alpha=0.01

    # input_path is path to data matrix with barcodes x features for all curated cell types in glomeruli
    # features = {'barcode','x','y'}
    input_path = 'glom_dat.csv'
    if path.exists(input_path):
        has_glom = True
        glom_dat = pd.read_csv(input_path,index_col=0)
        points = np.array(glom_dat[['x','y']])
        glom_alpha_shape = alphashape.alphashape(points,alpha=alpha)

    # input_path is path to data matrix with barcodes x features for all curated granular cell beads
    # features = {'barcode','x','y'}
    input_path = 'gc_dat.csv'
    if path.exists(input_path):
        has_gc = True
        gc_dat = pd.read_csv(input_path,index_col=0)
        points = np.array(gc_dat[['x','y']])
        gc_alpha_shape = alphashape.alphashape(points,alpha=alpha)

    # input_path is path to data matrix with barcodes x features for all curated MD beads
    # features = {'barcode','x','y'}
    input_path = 'MD_dat.csv'
    if path.exists(input_path):
        has_MD = True
        md_dat = pd.read_csv(input_path,index_col=0)
        points = np.array(md_dat[['x','y']])
        md_alpha_shape = alphashape.alphashape(points,alpha=alpha)

    if has_glom:
        markers = celltype_excluder(markers,glom_alpha_shape)
        if has_gc:
            markers = celltype_excluder(markers,gc_alpha_shape)
    if cell_type != 'TAL':
        if has_MD:
            markers = celltype_excluder(markers,md_alpha_shape)

# %% [markdown]
# ### KNN filtration protocol

# %%
# specify parameters
# k = number of nearest neighbors to consider per marker bead
# threshold = number of nearest neighbors to maintain
k = 80
threshold = 5

# %%
eroded = get_markers_in_struct(all_coords, np.array(markers[['barcode','x','y']]), k, threshold)
eroded = pd.DataFrame(eroded)
eroded = eroded.rename(columns={0:'barcode',1:'x',2:'y'})

# %% [markdown]
# ### Visualize eroded vs. maintained points

# %%
plt.figure(figsize=(10,10))
plt.scatter(markers['x'],markers['y'],s=3,c='b')
plt.scatter(eroded['x'],eroded['y'],s=3,c='r')
plt.xlim(0,6000)
plt.ylim(0,6000)
colors=['b','r']
texts=['cell type marker','cell type filter 1']
patches = [ plt.plot([],[], marker="o", ms=3, ls="", linewidth=0.6,color=colors[i], 
                label="{:s}".format(texts[i]) )[0]  for i in range(len(texts)) ]
plt.legend(handles=patches, bbox_to_anchor=(1, 0.5), 
        loc='center left', ncol=1,fontsize='medium')
plt.show()

# %% [markdown]
# ### File output

# %%
# out_path is path to output file
out_path = '/media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/XX.csv'
eroded.to_csv(out_path)

# %% [markdown]
# ### run KNN for a list of samples

# %%
# directory with coordinate files
input_dir_allCells = '/media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/*ogBeadLocations.csv'
input_dir_podo = '/media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/*BeadLocationsPodoTim.csv'

input_list_allCells = glob.glob(input_dir_allCells)
input_list_allCells = sorted(input_list_allCells)

input_list_podo = glob.glob(input_dir_podo)
input_list_podo = sorted(input_list_podo)

# Turn interactive plotting off
plt.ioff()

# cell type to-be-curated
cell_type = 'Podocyte'
# region of kidney 
section = 'cortex'


for ii in range(len(input_list_allCells)):

    print(ii)

    file_in_all = input_list_allCells[ii]
    file_in_podo = input_list_podo[ii]
    
    print(file_in_all)
    print(file_in_podo)

    # read in coordinate file with all
    allcells_dat=pd.read_csv(file_in_all , index_col=0)
    all_coords = np.array( allcells_dat )
    # read in coordinate file with podocytes
    markers = pd.read_csv( file_in_podo ,index_col=0 )
    
    ### KNN filtration protocol
    # specify parameters
    # k = number of nearest neighbors to consider per marker bead
    # threshold = number of nearest neighbors to maintain
    k = 25
    threshold = 5
    ### KNN filtration
    eroded = get_markers_in_struct(all_coords, np.array(markers[['barcode','x','y']]), k, threshold)
    eroded = pd.DataFrame(eroded)
    eroded = eroded.rename(columns={0:'barcode',1:'x',2:'y'})

    ### Visualize eroded vs. maintained points
    plt.figure(figsize=(10,10))
    plt.scatter(markers['x'],markers['y'],s=3,c='b')
    plt.scatter(eroded['x'],eroded['y'],s=3,c='r')
    plt.xlim(0,6000)
    plt.ylim(0,6000)
    colors=['b','r']
    texts=['cell type marker','cell type filter 1']
    patches = [ plt.plot([],[], marker="o", ms=3, ls="", linewidth=0.6,color=colors[i], 
                    label="{:s}".format(texts[i]) )[0]  for i in range(len(texts)) ]
    plt.legend(handles=patches, bbox_to_anchor=(1, 0.5), 
            loc='center left', ncol=1,fontsize='medium')
    plt.savefig( file_in_podo.replace("BeadLocationsPodoTim.csv","BeadLocationsPodoTim_erodedK80N5.png"))
    plt.close()

    # # out_path is path to output file
    # file_out = file_in_podo.replace("BeadLocationsPodoTim.csv","BeadLocationsPodoTim_erodedK50N5.csv")
    
    # eroded.to_csv(file_out)
# Out:
# 0
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713333_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713333_BeadLocationsPodoTim.csv
# 1
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713342_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713342_BeadLocationsPodoTim.csv
# 2
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713347_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713347_BeadLocationsPodoTim.csv
# 3
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713348_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713348_BeadLocationsPodoTim.csv
# 4
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713349_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713349_BeadLocationsPodoTim.csv
# 5
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713350_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713350_BeadLocationsPodoTim.csv
# 6
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713352_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713352_BeadLocationsPodoTim.csv
# 7
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713353_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713353_BeadLocationsPodoTim.csv
# 8
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713356_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713356_BeadLocationsPodoTim.csv
# 9
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713357_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713357_BeadLocationsPodoTim.csv
# 10
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713361_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713361_BeadLocationsPodoTim.csv
# 11
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713362_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713362_BeadLocationsPodoTim.csv
# 12
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713363_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713363_BeadLocationsPodoTim.csv
# 13
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713364_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713364_BeadLocationsPodoTim.csv
# 14
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713365_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713365_BeadLocationsPodoTim.csv
# 15
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713366_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713366_BeadLocationsPodoTim.csv
# 16
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/ogBeadLocations/GSM5713367_ogBeadLocations.csv
# /media/tim_nevelsk/WD_tim/PROJECTS/PODOCYTES/Spatial.Transcr/GSE190094_RAW/BTBR/podoClust/BeadLocationsPodoTim_2/GSM5713367_BeadLocationsPodoTim.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 43
#      41 threshold = 5
#      42 ### KNN filtration
# ---> 43 eroded = get_markers_in_struct(all_coords, np.array(markers[['barcode','x','y']]), k, threshold)
#      44 eroded = pd.DataFrame(eroded)
#      45 eroded = eroded.rename(columns={0:'barcode',1:'x',2:'y'})
#
# File ~/PROJECTS/PODOCYTE/DiseaseScore/Development_Validation/Spatial.trnscrptm/GSE190094/code/KNN_filtration.py:85, in get_markers_in_struct(all_coords, marker_coords_thresholded, n_neighbors, threshold)
#      83 nbrs_reduced = nbrs-np.identity(len(nbrs))
#      84 nbrs_reduced = remove_outgroup(nbrs_reduced, coords_labeled)
# ---> 85 nbrs_reduced = remove_outgroup(nbrs_reduced.T, coords_labeled)
#      87 eroded = erode(nbrs_reduced, coords_labeled, threshold)
#      88 eroded = np.delete(eroded, [3,4], 1)
#
# File ~/PROJECTS/PODOCYTE/DiseaseScore/Development_Validation/Spatial.trnscrptm/GSE190094/code/KNN_filtration.py:32, in remove_outgroup(nbrs, coords_labeled)
#      30 def remove_outgroup(nbrs, coords_labeled):
#      31     outgroup_indices = np.where(coords_labeled[:,3]==0)[0]
# ---> 32     nbrs[outgroup_indices,:] = np.array([0.]*len(nbrs))
#      34     return(nbrs)
#
# KeyboardInterrupt:
